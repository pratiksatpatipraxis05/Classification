# %% [markdown]
# - Objective: Predict behavior to retain customers. You can analyze all relevant customer data and develop focused customer retention programs.
# - Source - https://community.ibm.com/community/user/businessanalytics/blogs/steven-macko/2019/07/11/telco-customer-churn-1113
# - Considering the models applied I found that Ada-Boost with Logistic Regression gave the best f1 score of 63%.

# %% [markdown]
# # Importing Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import association_metrics as am
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.impute import KNNImputer
from scipy.stats import chi2_contingency
#from python.nominal import associations
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, roc_auc_score,classification_report,mean_squared_error
#from pyod.models.knn import KNN
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesRegressor
#from scikitplot.metrics import plot_cumulative_gain as pcg
from imblearn.over_sampling import SMOTE
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# # Reading and checking data

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# # Describe the Data

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include='object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     1448-PWKYE   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# freq          3473        2810            2785            3875
#
#        PaperlessBilling     PaymentMethod TotalCharges Churn
# count              7043              7043         7043  7043
# unique                2                 4         6531     2
# top                 Yes  Electronic check                 No
# freq               4171              2365           11  5174

# %% [markdown]
# # Checking for Null value

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Dropping Customer ID column as not required

# %%
df.drop('customerID',axis=1,inplace=True)

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'],errors='coerce')

# %%
df.isnull().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# ### Dropping NA values as it is less tha 5% of the data

# %%
df.dropna(axis=0,inplace=True)
df.shape
# Out:
# (7032, 20)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # Checking the Target Value

# %%
df['Churn'].value_counts()
# Out:
# No     5163
# Yes    1869
# Name: Churn, dtype: int64

# %%
# Counting percentages of 0
count_zero = (df['Churn'].value_counts()[0]/len(df['Churn']))*100
round(count_zero)
# Out:
# 73

# %%
# Couning perventages of 1
count_one = (df['Churn'].value_counts()[1]/len(df['Churn']))*100
round(count_one)
# Out:
# 27

# %% [markdown]
# # Checking Collinearity in the data

# %% [markdown]
# ### Cramer's V rule

# %%
df = df.apply(
    lambda x : x.astype('category') if x.dtype == 'O' else x
)

cramers_v = am.CramersV(df)

cfit = cramers_v.fit().round(2)
cfit
# Out:
#                   gender  Partner  Dependents  PhoneService  MultipleLines  \
# gender              1.00     0.00        0.01          0.01           0.01
# Partner             0.00     1.00        0.45          0.02           0.14
# Dependents          0.01     0.45        1.00          0.00           0.03
# PhoneService        0.01     0.02        0.00          1.00           1.00
# MultipleLines       0.01     0.14        0.03          1.00           1.00
# InternetService     0.01     0.00        0.18          0.45           0.40
# OnlineSecurity      0.02     0.15        0.19          0.18           0.23
# OnlineBackup        0.01     0.15        0.16          0.17           0.25
# DeviceProtection    0.00     0.17        0.16          0.17           0.25
# TechSupport         0.01     0.13        0.18          0.18           0.23
# StreamingTV         0.01     0.14        0.15          0.18           0.26
# StreamingMovies     0.01     0.13        0.14          0.18           0.26
# Contract            0.01     0.30        0.24          0.00           0.08
# PaperlessBilling    0.01     0.01        0.11          0.02           0.17
# PaymentMethod       0.02     0.16        0.15          0.01           0.17
# Churn               0.01     0.15        0.16          0.01           0.04
#
#                   InternetService  OnlineSecurity  OnlineBackup  \
# gender                       0.01            0.02          0.01
# Partner                      0.00            0.15          0.15
# Dependents                   0.18            0.19          0.16
# PhoneService                 0.45            0.18          0.17
# MultipleLines                0.40            0.23          0.25
# InternetService              1.00            0.72          0.71
# OnlineSecurity               0.72            1.00          0.72
# OnlineBackup                 0.71            0.72          1.00
# DeviceProtection             0.71            0.72          0.72
# TechSupport                  0.72            0.73          0.72
# StreamingTV                  0.72            0.71          0.71
# StreamingMovies              0.72            0.71          0.71
# Contract                     0.21            0.30          0.26
# PaperlessBilling             0.38            0.34          0.32
# PaymentMethod                0.31            0.30          0.28
# Churn                        0.32            0.35          0.29
#
#                   DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# gender                        0.00         0.01         0.01             0.01
# Partner                       0.17         0.13         0.14             0.13
# Dependents                    0.16         0.18         0.15             0.14
# PhoneService                  0.17         0.18         0.18             0.18
# MultipleLines                 0.25         0.23         0.26             0.26
# InternetService               0.71         0.72         0.72             0.72
# OnlineSecurity                0.72         0.73         0.71             0.71
# OnlineBackup                  0.72         0.72         0.71             0.71
# DeviceProtection              1.00         0.73         0.73             0.74
# TechSupport                   0.73         1.00         0.72             0.72
# StreamingTV                   0.73         0.72         1.00             0.77
# StreamingMovies               0.74         0.72         0.77             1.00
# Contract                      0.30         0.33         0.24             0.24
# PaperlessBilling              0.32         0.33         0.34             0.33
# PaymentMethod                 0.29         0.31         0.27             0.27
# Churn                         0.28         0.34         0.23             0.23
#
#                   Contract  PaperlessBilling  PaymentMethod  Churn
# gender                0.01              0.01           0.02   0.01
# Partner               0.30              0.01           0.16   0.15
# Dependents            0.24              0.11           0.15   0.16
# PhoneService          0.00              0.02           0.01   0.01
# MultipleLines         0.08              0.17           0.17   0.04
# InternetService       0.21              0.38           0.31   0.32
# OnlineSecurity        0.30              0.34           0.30   0.35
# OnlineBackup          0.26              0.32           0.28   0.29
# DeviceProtection      0.30              0.32           0.29   0.28
# TechSupport           0.33              0.33           0.31   0.34
# StreamingTV           0.24              0.34           0.27   0.23
# StreamingMovies       0.24              0.33           0.27   0.23
# Contract              1.00              0.18           0.27   0.41
# PaperlessBilling      0.18              1.00           0.25   0.19
# PaymentMethod         0.27              0.25           1.00   0.30
# Churn                 0.41              0.19           0.30   1.00

# %%
plt.figure(figsize=(15,15))
sns.heatmap(cramers_v.fit().round(2),annot=True)

# %%
df.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen        1.000000  0.015683        0.219874      0.102411
# tenure               0.015683  1.000000        0.246862      0.825880
# MonthlyCharges       0.219874  0.246862        1.000000      0.651065
# TotalCharges         0.102411  0.825880        0.651065      1.000000

# %%
df['Churn'] = df.Churn.map({'No':0,'Yes':1})
df['Churn'] = df['Churn'].astype('int64')

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#    Churn
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %%
b,a = dmatrices('Churn ~ SeniorCitizen + tenure + MonthlyCharges + TotalCharges',data=df,return_type='dataframe')

vif  = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(a.values, i) for i in range(a.shape[1])]
vif['variable'] = a.columns

vif
# Out:
#          VIF        variable
# 0  14.989702       Intercept
# 1   1.054455   SeniorCitizen
# 2   5.847215          tenure
# 3   3.314481  MonthlyCharges
# 4   9.543891    TotalCharges

# %% [markdown]
# ### Dropping the TotalCharges as having high VIF

# %%
df = df.drop('TotalCharges',axis=1)

# %% [markdown]
# # Checking the Distribution

# %%
features = []

for i in df.columns:
    unique_values = df[i].nunique()  
    if unique_values < 5:
        features.append(i)
features
# Out:
# ['gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
features.remove('Churn')

# %%
plt.figure(figsize=(10, 30))

for i, column in enumerate(features):
    plt.subplot((len(features) + 1) // 2, 2, i + 1)  

    sns.countplot(data=df, x=column, hue="Churn")

    plt.title(column, fontsize = 15, color = "red")
    plt.xticks(rotation=45)

plt.tight_layout(pad=2.0)
plt.show()

# %%
categorical_cols = df.select_dtypes(exclude = np.number).columns.tolist()
numerical_cols = df.select_dtypes(include = np.number).columns.tolist()

# %%
length= len(categorical_cols)
length
# Out:
# 15

# %%
df.head(10)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
# 5  Female              0      No         No       8          Yes
# 6    Male              0      No        Yes      22          Yes
# 7  Female              0      No         No      10           No
# 8  Female              0     Yes         No      28          Yes
# 9    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
# 5               Yes     Fiber optic             No           No
# 6               Yes     Fiber optic             No          Yes
# 7  No phone service             DSL            Yes           No
# 8               Yes     Fiber optic             No           No
# 9                No             DSL            Yes          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
# 5              Yes          No         Yes             Yes  Month-to-month
# 6               No          No         Yes              No  Month-to-month
# 7               No          No          No              No  Month-to-month
# 8              Yes         Yes         Yes             Yes  Month-to-month
# 9               No          No          No              No        One year
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  Churn
# 0              Yes           Electronic check           29.85      0
# 1               No               Mailed check           56.95      0
# 2              Yes               Mailed check           53.85      1
# 3               No  Bank transfer (automatic)           42.30      0
# 4              Yes           Electronic check           70.70      1
# 5              Yes           Electronic check           99.65      1
# 6              Yes    Credit card (automatic)           89.10      0
# 7               No               Mailed check           29.75      0
# 8              Yes           Electronic check          104.80      1
# 9               No  Bank transfer (automatic)           56.15      0

# %%
df.nunique()
# Out:
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                72
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1584
# Churn                  2
# dtype: int64

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# E:\Anaconda\New folder\lib\site-packages\pandas\core\frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2495                 if "object" in counts or self.index._is_memory_usage_qualified():
#    2496                     size_qualifier = "+"
# -> 2497             mem_usage = self.memory_usage(index=True, deep=deep).sum()
#    2498             lines.append(f"memory usage: {_sizeof_fmt(mem_usage, size_qualifier)}\n")
#    2499         fmt.buffer_put_lines(buf, lines)
#
# E:\Anaconda\New folder\lib\site-packages\pandas\core\frame.py in memory_usage(self, index, deep)
#    2588         )
#    2589         if index:
# -> 2590             result = Series(self.index.memory_usage(deep=deep), index=["Index"]).append(
#    2591                 result
#    2592             )
#
# E:\Anaconda\New folder\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     303                     data = data.copy()
#     304             else:
# --> 305                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     306
#     307                 data = SingleBlockManager(data, index, fastpath=True)
#
# E:\Anaconda\New folder\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     463                 value = maybe_cast_to_datetime(value, dtype)
#     464
# --> 465             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     466
#     467         else:
#
# E:\Anaconda\New folder\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1459                 value = ensure_str(value)
#    1460
# -> 1461         subarr = np.empty(length, dtype=dtype)
#    1462         subarr.fill(value)
#    1463
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %% [markdown]
# # Dummification of the Multiclass Categorical fields

# %%
features = df.drop('Churn',axis=1)
tg = df['Churn']

for i in features:
    if df[i].dtypes == 'category':
        woe = (pd.crosstab(df[i],tg,normalize='columns').assign(woe=lambda dfx: np.log(dfx[1] / dfx[0])).assign(iv=lambda dfx: np.sum(dfx['woe']*(dfx[1]-dfx[0]))))
        print(woe)
# Out:
# Churn          0         1       woe        iv
# gender
# Female  0.492737  0.502408  0.019437  0.000374
# Male    0.507263  0.497592 -0.019249  0.000374
# Churn         0         1       woe        iv
# Partner
# No       0.4724  0.642055  0.306848  0.117877
# Yes      0.5276  0.357945 -0.387958  0.117877
# Churn              0         1       woe        iv
# Dependents
# No          0.656595  0.825575  0.229013  0.153169
# Yes         0.343405  0.174425 -0.677417  0.153169
# Churn               0         1       woe        iv
# PhoneService
# No            0.09878  0.090958 -0.082498  0.000713
# Yes           0.90122  0.909042  0.008642  0.000713
# Churn                    0         1       woe        iv
# MultipleLines
# No                0.491187  0.454254 -0.078170  0.008169
# No phone service  0.098780  0.090958 -0.082498  0.008169
# Yes               0.410033  0.454789  0.103595  0.008169
# Churn                   0         1       woe        iv
# InternetService
# DSL              0.379043  0.245586 -0.434003  0.615253
# Fiber optic      0.348441  0.693954  0.688937  0.615253
# No               0.272516  0.060460 -1.505713  0.615253
# Churn                       0         1       woe        iv
# OnlineSecurity
# No                   0.394344  0.781701  0.684248  0.715292
# No internet service  0.272516  0.060460 -1.505713  0.715292
# Yes                  0.333140  0.157838 -0.746990  0.715292
# Churn                       0         1       woe        iv
# OnlineBackup
# No                   0.359094  0.659711  0.608219  0.526488
# No internet service  0.272516  0.060460 -1.505713  0.526488
# Yes                  0.368390  0.279829 -0.274966  0.526488
# Churn                       0        1       woe       iv
# DeviceProtection
# No                   0.364710  0.64794  0.574694  0.49761
# No internet service  0.272516  0.06046 -1.505713  0.49761
# Yes                  0.362774  0.29160 -0.218397  0.49761
# Churn                       0         1       woe        iv
# TechSupport
# No                   0.392408  0.773676  0.678852  0.697108
# No internet service  0.272516  0.060460 -1.505713  0.697108
# Yes                  0.335077  0.165864 -0.703190  0.697108
# Churn                       0         1       woe        iv
# StreamingTV
# No                   0.361611  0.504013  0.332031  0.378716
# No internet service  0.272516  0.060460 -1.505713  0.378716
# Yes                  0.365873  0.435527  0.174272  0.378716
# Churn                       0         1       woe        iv
# StreamingMovies
# No                   0.356963  0.501873  0.340714  0.379851
# No internet service  0.272516  0.060460 -1.505713  0.379851
# Yes                  0.370521  0.437667  0.166549  0.379851
# Churn                  0         1       woe        iv
# Contract
# Month-to-month  0.429983  0.885500  0.722408  1.233189
# One year        0.252954  0.088818 -1.046622  1.233189
# Two year        0.317064  0.025682 -2.513305  1.233189
# Churn                    0         1       woe        iv
# PaperlessBilling
# No                0.463878  0.250936 -0.614421  0.202056
# Yes               0.536122  0.749064  0.334461  0.202056
# Churn                             0         1       woe        iv
# PaymentMethod
# Bank transfer (automatic)  0.248693  0.138042 -0.588662  0.455756
# Credit card (automatic)    0.249661  0.124131 -0.698770  0.455756
# Electronic check           0.250629  0.573034  0.826969  0.455756
# Mailed check               0.251017  0.164794 -0.420824  0.455756

# %%
for i in features:
    if df[i].dtypes == 'category':
        woe = (pd.crosstab(df[i],tg,normalize='columns').assign(woe=lambda dfx: np.log(dfx[1] / dfx[0])).assign(iv=lambda dfx: np.sum(dfx['woe']*(dfx[1]-dfx[0]))))
        woe_dict = woe['woe'].to_dict()
        df = df.replace({i: woe_dict})

# %%
df.head(15)
# Out:
#       gender  SeniorCitizen   Partner  Dependents  tenure  PhoneService  \
# 0   0.019437              0 -0.387958    0.229013       1     -0.082498
# 1  -0.019249              0  0.306848    0.229013      34      0.008642
# 2  -0.019249              0  0.306848    0.229013       2      0.008642
# 3  -0.019249              0  0.306848    0.229013      45     -0.082498
# 4   0.019437              0  0.306848    0.229013       2      0.008642
# 5   0.019437              0  0.306848    0.229013       8      0.008642
# 6  -0.019249              0  0.306848   -0.677417      22      0.008642
# 7   0.019437              0  0.306848    0.229013      10     -0.082498
# 8   0.019437              0 -0.387958    0.229013      28      0.008642
# 9  -0.019249              0  0.306848   -0.677417      62      0.008642
# 10 -0.019249              0 -0.387958   -0.677417      13      0.008642
# 11 -0.019249              0  0.306848    0.229013      16      0.008642
# 12 -0.019249              0 -0.387958    0.229013      58      0.008642
# 13 -0.019249              0  0.306848    0.229013      49      0.008642
# 14 -0.019249              0  0.306848    0.229013      25      0.008642
#
#     MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0       -0.082498        -0.434003        0.684248     -0.274966
# 1       -0.078170        -0.434003       -0.746990      0.608219
# 2       -0.078170        -0.434003       -0.746990     -0.274966
# 3       -0.082498        -0.434003       -0.746990      0.608219
# 4       -0.078170         0.688937        0.684248      0.608219
# 5        0.103595         0.688937        0.684248      0.608219
# 6        0.103595         0.688937        0.684248     -0.274966
# 7       -0.082498        -0.434003       -0.746990      0.608219
# 8        0.103595         0.688937        0.684248      0.608219
# 9       -0.078170        -0.434003       -0.746990     -0.274966
# 10      -0.078170        -0.434003       -0.746990      0.608219
# 11      -0.078170        -1.505713       -1.505713     -1.505713
# 12       0.103595         0.688937        0.684248      0.608219
# 13       0.103595         0.688937        0.684248     -0.274966
# 14      -0.078170         0.688937       -0.746990      0.608219
#
#     DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0           0.574694     0.678852     0.332031         0.340714  0.722408
# 1          -0.218397     0.678852     0.332031         0.340714 -1.046622
# 2           0.574694     0.678852     0.332031         0.340714  0.722408
# 3          -0.218397    -0.703190     0.332031         0.340714 -1.046622
# 4           0.574694     0.678852     0.332031         0.340714  0.722408
# 5          -0.218397     0.678852     0.174272         0.166549  0.722408
# 6           0.574694     0.678852     0.174272         0.340714  0.722408
# 7           0.574694     0.678852     0.332031         0.340714  0.722408
# 8          -0.218397    -0.703190     0.174272         0.166549  0.722408
# 9           0.574694     0.678852     0.332031         0.340714 -1.046622
# 10          0.574694     0.678852     0.332031         0.340714  0.722408
# 11         -1.505713    -1.505713    -1.505713        -1.505713 -2.513305
# 12         -0.218397     0.678852     0.174272         0.166549 -1.046622
# 13         -0.218397     0.678852     0.174272         0.166549  0.722408
# 14         -0.218397    -0.703190     0.174272         0.166549  0.722408
#
#     PaperlessBilling  PaymentMethod  MonthlyCharges  Churn
# 0           0.334461       0.826969           29.85      0
# 1          -0.614421      -0.420824           56.95      0
# 2           0.334461      -0.420824           53.85      1
# 3          -0.614421      -0.588662           42.30      0
# 4           0.334461       0.826969           70.70      1
# 5           0.334461       0.826969           99.65      1
# 6           0.334461      -0.698770           89.10      0
# 7          -0.614421      -0.420824           29.75      0
# 8           0.334461       0.826969          104.80      1
# 9          -0.614421      -0.588662           56.15      0
# 10          0.334461      -0.420824           49.95      0
# 11         -0.614421      -0.698770           18.95      0
# 12         -0.614421      -0.698770          100.35      0
# 13          0.334461      -0.588662          103.70      1
# 14          0.334461       0.826969          105.50      0

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)

# %%
features_to_pca = ["InternetService","OnlineBackup","DeviceProtection","StreamingTV","StreamingMovies",]

# %%
df_pca = df[features_to_pca]

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_pca)


result = pd.DataFrame(pca_result, columns=['PC1', 'PC2'])
result
# Out:
#            PC1       PC2
# 0    -0.552923  0.516952
# 1    -0.596110  0.591468
# 2    -0.552923  0.516952
# 3    -0.596110  0.591468
# 4    -1.469855 -0.160575
# ...        ...       ...
# 7027 -0.451888  0.548322
# 7028 -0.564399 -0.737231
# 7029 -0.955134  0.820965
# 7030 -1.469855 -0.160575
# 7031 -0.966609 -0.433218
#
# [7032 rows x 2 columns]

# %%
df = df.drop(columns=features_to_pca)

# %%
df = pd.concat([df, result], axis=1)

# %%
df.head(10)
# Out:
#      gender  SeniorCitizen   Partner  Dependents  tenure  PhoneService  \
# 0  0.019437            0.0 -0.387958    0.229013     1.0     -0.082498
# 1 -0.019249            0.0  0.306848    0.229013    34.0      0.008642
# 2 -0.019249            0.0  0.306848    0.229013     2.0      0.008642
# 3 -0.019249            0.0  0.306848    0.229013    45.0     -0.082498
# 4  0.019437            0.0  0.306848    0.229013     2.0      0.008642
# 5  0.019437            0.0  0.306848    0.229013     8.0      0.008642
# 6 -0.019249            0.0  0.306848   -0.677417    22.0      0.008642
# 7  0.019437            0.0  0.306848    0.229013    10.0     -0.082498
# 8  0.019437            0.0 -0.387958    0.229013    28.0      0.008642
# 9 -0.019249            0.0  0.306848   -0.677417    62.0      0.008642
#
#    MultipleLines  OnlineSecurity  TechSupport  Contract  PaperlessBilling  \
# 0      -0.082498        0.684248     0.678852  0.722408          0.334461
# 1      -0.078170       -0.746990     0.678852 -1.046622         -0.614421
# 2      -0.078170       -0.746990     0.678852  0.722408          0.334461
# 3      -0.082498       -0.746990    -0.703190 -1.046622         -0.614421
# 4      -0.078170        0.684248     0.678852  0.722408          0.334461
# 5       0.103595        0.684248     0.678852  0.722408          0.334461
# 6       0.103595        0.684248     0.678852  0.722408          0.334461
# 7      -0.082498       -0.746990     0.678852  0.722408         -0.614421
# 8       0.103595        0.684248    -0.703190  0.722408          0.334461
# 9      -0.078170       -0.746990     0.678852 -1.046622         -0.614421
#
#    PaymentMethod  MonthlyCharges  Churn       PC1       PC2
# 0       0.826969           29.85    0.0 -0.552923  0.516952
# 1      -0.420824           56.95    0.0 -0.596110  0.591468
# 2      -0.420824           53.85    1.0 -0.552923  0.516952
# 3      -0.588662           42.30    0.0 -0.596110  0.591468
# 4       0.826969           70.70    1.0 -1.469855 -0.160575
# 5       0.826969           99.65    1.0 -0.966609 -0.433218
# 6      -0.698770           89.10    0.0 -0.999121 -0.484846
# 7      -0.420824           29.75    0.0 -0.955134  0.820965
# 8       0.826969          104.80    1.0 -0.966609 -0.433218
# 9      -0.588662           56.15    0.0 -0.552923  0.516952

# %%
df.isnull().sum()
# Out:
# gender              11
# SeniorCitizen       11
# Partner             11
# Dependents          11
# tenure              11
# PhoneService        11
# MultipleLines       11
# OnlineSecurity      11
# TechSupport         11
# Contract            11
# PaperlessBilling    11
# PaymentMethod       11
# MonthlyCharges      11
# Churn               11
# PC1                 11
# PC2                 11
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)
df.shape
# Out:
# (7021, 16)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# # Checking the Information Value

# %%
for i in features:
    if features[i].dtypes == 'category':
        woe = (pd.crosstab(features[i],tg,normalize='columns').assign(woe=lambda dfx: np.log(dfx[1] / dfx[0])).assign(iv=lambda dfx: np.sum(dfx['woe']*(dfx[1]-dfx[0]))))
        print(woe['iv'])
#woe
# Out:
# gender
# Female    0.000374
# Male      0.000374
# Name: iv, dtype: float64
# Partner
# No     0.117877
# Yes    0.117877
# Name: iv, dtype: float64
# Dependents
# No     0.153169
# Yes    0.153169
# Name: iv, dtype: float64
# PhoneService
# No     0.000713
# Yes    0.000713
# Name: iv, dtype: float64
# MultipleLines
# No                  0.008169
# No phone service    0.008169
# Yes                 0.008169
# Name: iv, dtype: float64
# InternetService
# DSL            0.615253
# Fiber optic    0.615253
# No             0.615253
# Name: iv, dtype: float64
# OnlineSecurity
# No                     0.715292
# No internet service    0.715292
# Yes                    0.715292
# Name: iv, dtype: float64
# OnlineBackup
# No                     0.526488
# No internet service    0.526488
# Yes                    0.526488
# Name: iv, dtype: float64
# DeviceProtection
# No                     0.49761
# No internet service    0.49761
# Yes                    0.49761
# Name: iv, dtype: float64
# TechSupport
# No                     0.697108
# No internet service    0.697108
# Yes                    0.697108
# Name: iv, dtype: float64
# StreamingTV
# No                     0.378716
# No internet service    0.378716
# Yes                    0.378716
# Name: iv, dtype: float64
# StreamingMovies
# No                     0.379851
# No internet service    0.379851
# Yes                    0.379851
# Name: iv, dtype: float64
# Contract
# Month-to-month    1.233189
# One year          1.233189
# Two year          1.233189
# Name: iv, dtype: float64
# PaperlessBilling
# No     0.202056
# Yes    0.202056
# Name: iv, dtype: float64
# PaymentMethod
# Bank transfer (automatic)    0.455756
# Credit card (automatic)      0.455756
# Electronic check             0.455756
# Mailed check                 0.455756
# Name: iv, dtype: float64

# %% [markdown]
# # Splitting Predictors and Target

# %%
X = df.drop('Churn',axis=1)
y = df['Churn']

# %% [markdown]
# Important: PaymentMethod,StreamingMovies,StreamingTV,DeviceProtection
#
# Suspicious: Contract,TechSupport, OnlineBackup, OnlineSecurity, InternetService
#
# Medium: PaperlessBilling, Dependents, Partner
#
# Weak:
#
# Useless: MultipleLines, PhoneService, gender

# %% [markdown]
# # Feature Selection

# %%
etr_model = ExtraTreesRegressor()
etr_model.fit(X,y)
etr_model.feature_importances_
# Out:
# array([0.04106374, 0.02883165, 0.03602751, 0.03049593, 0.16150545,
#        0.01085081, 0.03014971, 0.06012934, 0.03631315, 0.1322979 ,
#        0.02940599, 0.05971549, 0.16263703, 0.08767315, 0.09290316])

# %%
feature_imp = pd.Series(etr_model.feature_importances_,index=X.columns)
feature_imp.nlargest(20).plot(kind='barh')

# %%
feature = ['Contract','tenure','PaymentMethod','MonthlyCharges','PC1','PC2','Partner','Dependents']

# %%
X = df[feature]

# %%
X = df.drop('Churn',axis=1)
y = df['Churn']

# %% [markdown]
# # Performing Train Test Split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=101)

# %% [markdown]
# # Scaling the data

# %%
sc = StandardScaler()

# %%
X_train = pd.DataFrame(sc.fit_transform(X_train),columns=X_train.columns)
X_test = pd.DataFrame(sc.transform(X_test),columns=X_test.columns)

# %% [markdown]
# # Logistic regression

# %%
model_lr = LogisticRegression(multi_class='ovr',penalty='l2',max_iter=2000,random_state=101)

# %%
np.mean(cross_val_score(model_lr,X_train,y_train,cv=5))
# Out:
# 0.7950504336693465

# %%
model_lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=2000, multi_class='ovr', random_state=101)

# %%
f1_score(y_train,model_lr.predict(X_train))
# Out:
# 0.5811155668975574

# %%
y_pred_lr = model_lr.predict(X_test)

# %%
model_lr.score(X_test,y_test)
# Out:
# 0.8192170818505338

# %%
f1_score(y_test,y_pred_lr)
# Out:
# 0.6151515151515151

# %%
cm = confusion_matrix(y_test,y_pred_lr)

# %%
cm_display_lr = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])

# %%
cm_display_lr.plot()
plt.show()

# %%
auc_score = roc_auc_score(y_test,y_pred_lr)
auc_score
# Out:
# 0.7329029705253448

# %%
print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.91      0.88      1037
#          1.0       0.70      0.55      0.62       368
#
#     accuracy                           0.82      1405
#    macro avg       0.77      0.73      0.75      1405
# weighted avg       0.81      0.82      0.81      1405

# %%
probs = model_lr.predict_proba(X_test)

# %%
pcg(y_test,probs)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-31c1959c40b2> in <module>
# ----> 1 pcg(y_test,probs)
#       2 plt.show()
#
# NameError: name 'pcg' is not defined

# %%
param_grid = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga']
}

# %%
grid_search = GridSearchCV(model_lr, param_grid, cv=5, scoring='accuracy')

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=LogisticRegression(max_iter=2000, multi_class='ovr',
#                                           random_state=101),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'saga']},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
grid_search.best_score_
# Out:
# 0.7950504336693465

# %%
best_model = grid_search.best_estimator_

# %%
test_accuracy = best_model.score(X_test, y_test)
test_accuracy
# Out:
# 0.8177935943060498

# %%
f1_score(y_train,best_model.predict(X_train))
# Out:
# 0.5826656955571741

# %%
y_pred_lr1 = best_model.predict(X_test)

# %%
auc_score = roc_auc_score(y_test,y_pred_lr1)
auc_score
# Out:
# 0.732815185946082

# %%
print(classification_report(y_test, y_pred_lr1))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.91      0.88      1037
#          1.0       0.69      0.55      0.61       368
#
#     accuracy                           0.82      1405
#    macro avg       0.77      0.73      0.75      1405
# weighted avg       0.81      0.82      0.81      1405

# %%
probs_grid = best_model.predict_proba(X_test)

# %%
pcg(y_test,probs_grid)
plt.show()

# %% [markdown]
# # KNN Classification

# %%
error = []
for i in range(1, 10):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    y_pred_KNN = knn.predict(X_test)
    error.append(np.sqrt(mean_squared_error(y_test, y_pred_KNN)))

plt.figure(figsize=(16,8))
plt.plot(range(1, 10), error, 'bx-')
plt.xlabel('k')
plt.ylabel('error')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
model_knn = KNeighborsClassifier(n_neighbors = 5)

# %%
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
np.mean(cross_val_score(model_knn,X_train,y_train,cv=5))
# Out:
# 0.7553404549963082

# %%
f1_score(y_train,model_knn.predict(X_train))
# Out:
# 0.6614509246088194

# %%
y_pred_knn = model_knn.predict(X_test)

# %%
y_test.value_counts()
# Out:
# 0.0    1037
# 1.0     368
# Name: Churn, dtype: int64

# %%
f1_score(y_test,y_pred_knn)
# Out:
# 0.5086705202312138

# %%
cm = confusion_matrix(y_test,y_pred_lr)
cm_display_lr = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])
cm_display_lr.plot()
plt.show()

# %%
auc_score = roc_auc_score(y_test,y_pred_knn)
auc_score
# Out:
# 0.667770743365058

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.86      0.84      1037
#          1.0       0.54      0.48      0.51       368
#
#     accuracy                           0.76      1405
#    macro avg       0.68      0.67      0.67      1405
# weighted avg       0.75      0.76      0.75      1405

# %% [markdown]
# # DecisionTree Classification

# %%
model_dt = DecisionTreeClassifier(max_depth=7,random_state=0)

# %%
np.mean(cross_val_score(model_dt,X_train,y_train,cv=5))
# Out:
# 0.7751057633499492

# %%
model_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, random_state=0)

# %%
f1_score(y_train,model_dt.predict(X_train))
# Out:
# 0.6565758493104609

# %%
y_pred_dt = model_dt.predict(X_test)

# %%
f1_score(y_test,y_pred_dt)
# Out:
# 0.6096551724137931

# %%
cm = confusion_matrix(y_test,y_pred_dt)
cm_display_lr = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])
cm_display_lr.plot()
plt.show()

# %%
auc_score = roc_auc_score(y_test,y_pred_dt)
auc_score
# Out:
# 0.7346979686386316

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.87      0.86      1037
#          1.0       0.62      0.60      0.61       368
#
#     accuracy                           0.80      1405
#    macro avg       0.74      0.73      0.74      1405
# weighted avg       0.80      0.80      0.80      1405

# %%
probs = model_dt.predict_proba(X_test)

# %%
pcg(y_test,probs)
plt.show()

# %% [markdown]
# # Random Forest Classification

# %%
model_rf = RandomForestClassifier(max_depth=11,random_state=0)

# %%
np.mean(cross_val_score(model_rf,X_train,y_train,cv=5))
# Out:
# 0.7952280527184745

# %%
model_rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=11, random_state=0)

# %%
f1_score(y_train,model_rf.predict(X_train))
# Out:
# 0.8566433566433567

# %%
y_pred_rf = model_rf.predict(X_test)

# %%
f1_score(y_test,y_pred_rf)
# Out:
# 0.5805422647527911

# %%
auc_score = roc_auc_score(y_test,y_pred_rf)
auc_score
# Out:
# 0.71015628275544

# %%
cm = confusion_matrix(y_test,y_pred_rf)
cm_display_lr = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])
cm_display_lr.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.93      0.88      1037
#          1.0       0.70      0.49      0.58       368
#
#     accuracy                           0.81      1405
#    macro avg       0.77      0.71      0.73      1405
# weighted avg       0.80      0.81      0.80      1405

# %%
probs = model_rf.predict_proba(X_test)

# %%
pcg(y_test,probs)
plt.show()

# %% [markdown]
# # Ada Boost on Logistic Regression

# %%
classifier = AdaBoostClassifier(
    LogisticRegression(multi_class='ovr',penalty='l2',max_iter=2000),
    n_estimators = 200
)

# %%
classifier.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(base_estimator=LogisticRegression(max_iter=2000,
#                                                      multi_class='ovr'),
#                    n_estimators=200)

# %%
f1_score(y_train,classifier.predict(X_train))
# Out:
# 0.5831517792302107

# %%
y_pred_ada = classifier.predict(X_test)

# %%
f1_score(y_test,y_pred_ada)
# Out:
# 0.6304675716440422

# %% [markdown]
# # Applying SMOTE

# %%
smt = SMOTE(random_state=42)
X_train, y_train = smt.fit_resample(X_train, y_train)

# %%
count_zero = (y_train.value_counts()[0]/len(y_train))*100
count_zero
# Out:
# 50.0

# %%
count_one = (y_train.value_counts()[1]/len(y_train))*100
count_one
# Out:
# 50.0

# %% [markdown]
# # Logistic Regression

# %%
model_lr_smt = LogisticRegression(multi_class='ovr',penalty='l2',max_iter=2000)

# %%
np.mean(cross_val_score(model_lr_smt,X_train,y_train,cv=5))
# Out:
# 0.7685784244374886

# %%
model_lr_smt.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=2000, multi_class='ovr')

# %%
f1_score(y_train,model_lr_smt.predict(X_train))
# Out:
# 0.7783708517057322

# %%
y_pred_lr_smt = model_lr_smt.predict(X_test)

# %%
f1_score(y_test,y_pred_lr_smt)
# Out:
# 0.6267682263329706

# %%
auc_score = roc_auc_score(y_test,y_pred_lr_smt)
auc_score
# Out:
# 0.7644962475367909

# %%
cm = confusion_matrix(y_test,y_pred_lr_smt)
cm_display_lr = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])
cm_display_lr.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred_lr_smt))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.75      0.82      1037
#          1.0       0.52      0.78      0.63       368
#
#     accuracy                           0.76      1405
#    macro avg       0.71      0.76      0.72      1405
# weighted avg       0.81      0.76      0.77      1405

# %%
probs = model_lr_smt.predict_proba(X_test)

# %%
pcg(y_test,probs)
plt.show()

# %% [markdown]
# # KNN

# %%
error = []
for i in range(1, 10):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    y_pred_KNN = knn.predict(X_test)
    error.append(np.sqrt(mean_squared_error(y_test, y_pred_KNN)))

plt.figure(figsize=(16,8))
plt.plot(range(1, 10), error, 'bx-')
plt.xlabel('k')
plt.ylabel('error')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
knn_smt = KNeighborsClassifier(n_neighbors = 4)

# %%
knn_smt.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
f1_score(y_train,knn_smt.predict(X_train))
# Out:
# 0.895828367103695

# %%
y_pred_knn_smt = knn_smt.predict(X_test)

# %%
f1_score(y_test,y_pred_knn_smt)
# Out:
# 0.5632040050062578

# %%
auc_score = roc_auc_score(y_test,y_pred_knn_smt)
auc_score
# Out:
# 0.7063815458471343

# %%
cm = confusion_matrix(y_test,y_pred_knn_smt)
cm_display_lr = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])
cm_display_lr.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred_knn_smt))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.80      0.83      1037
#          1.0       0.52      0.61      0.56       368
#
#     accuracy                           0.75      1405
#    macro avg       0.69      0.71      0.69      1405
# weighted avg       0.77      0.75      0.76      1405

# %%
probs_knn_smt = knn_smt.predict_proba(X_test)

# %%
pcg(y_test,probs_knn_smt)
plt.show()

# %% [markdown]
# # Decision Tree

# %%
model_dt_smt = DecisionTreeClassifier(max_depth=5,random_state=0)

# %%
model_dt_smt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=0)

# %%
f1_score(y_train,model_dt_smt.predict(X_train))
# Out:
# 0.8050524308865585

# %%
model_dt_smt.get_depth()
# Out:
# 5

# %%
y_pred_dt_smt = model_dt_smt.predict(X_test)

# %%
f1_score(y_test,y_pred_dt_smt)
# Out:
# 0.6222222222222222

# %%
auc_score = roc_auc_score(y_test,y_pred_dt_smt)
auc_score
# Out:
# 0.7548556664290804

# %%
cm = confusion_matrix(y_test,y_pred_dt_smt)
cm_display_lr = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])
cm_display_lr.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred_lr_smt))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.75      0.82      1037
#          1.0       0.52      0.78      0.63       368
#
#     accuracy                           0.76      1405
#    macro avg       0.71      0.76      0.72      1405
# weighted avg       0.81      0.76      0.77      1405

# %%
probs_dt_smt = model_dt_smt.predict_proba(X_test)

# %%
pcg(y_test,probs_dt_smt)
plt.show()

# %% [markdown]
# # RandomForest

# %%
model_rf_smt = RandomForestClassifier(max_depth=4,random_state=0)

# %%
model_rf_smt.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=4, random_state=0)

# %%
f1_score(y_train,model_rf_smt.predict(X_train))
# Out:
# 0.8005572324123521

# %%
y_pred_rd_smt = model_rf_smt.predict(X_test)

# %%
f1_score(y_test,y_pred_rd_smt)
# Out:
# 0.6321709786276715

# %%
auc_score = roc_auc_score(y_test,y_pred_rd_smt)
auc_score
# Out:
# 0.7660750597459227

# %%
cm = confusion_matrix(y_test,y_pred_rd_smt)
cm_display_lr = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])
cm_display_lr.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred_rd_smt))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.77      0.83      1037
#          1.0       0.54      0.76      0.63       368
#
#     accuracy                           0.77      1405
#    macro avg       0.72      0.77      0.73      1405
# weighted avg       0.81      0.77      0.78      1405

# %%
probs_rf_smt = model_rf_smt.predict_proba(X_test)

# %%
pcg(y_test,probs_rf_smt)
plt.show()

# %% [markdown]
# # Ada Boost

# %%
classifier = AdaBoostClassifier(
    LogisticRegression(multi_class='ovr',penalty='l2',max_iter=2000),
    n_estimators = 200
)

# %%
classifier.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(base_estimator=LogisticRegression(max_iter=2000,
#                                                      multi_class='ovr'),
#                    n_estimators=200)

# %%
f1_score(y_train,classifier.predict(X_train))
# Out:
# 0.7791907514450866

# %%
y_pred_ada_smt = classifier.predict(X_test)

# %%
f1_score(y_test,y_pred_ada_smt)
# Out:
# 0.6270270270270271
